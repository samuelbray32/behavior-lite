# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.bootstrapTest import bootstrap_traces
from tools.results import data_of_interest
from tools.results_step import rnai_response_layered

# %% [markdown]
# ## Compiled Plot
# Compiles all valid valid datasets at each power in "powers" for each knockdownlisted in the interest list and runs bootstrap estimates on the complete set of traces
#
# Note: printout lists are all datasets that are compiled for each condition.  Please check that what is being compiled is what you want!

# %%
n_boot = 1e2
statistic=np.median
comparison = 'diff'

interest = ['pc2']#['spp1','ppp1','eye532','eye531']#['4mnthstarve','starve10w']#['if1+cali','if1+estrella','if1+cali+estrella',]##'arx','35mmBiopsyPostEyespot','pc2']#[]#['spot']#['spot']#'pc2','gad','chat','tbh','th']
exclude = []
powers = [64,128]
statistic = np.median
comparison = 'rel'
fig, ax = rnai_response_layered(interest,exclude,n_boot,statistic,measure_compare=comparison,
                                conf_interval=99, stat_testing=True,powers=powers)

# ax[0,].set_xlim(-3,15)
# ax[0,].set_ylim(0,1.5)
# Out:
# WT_30m2h64bp ['121621WT_30m2h64bp', '051122WT_30m2h64bp', '051822WT_30m2h64bp']
# WT_30m2h128bp ['121621WT_30m2h128bp']
# pc2
# tbh+pc2_30m2h64bp
# tcf1+pc2_30m2h64bp
# chat+pc2_30m2h64bp
# 070522th+pc2_30m2h64bp
# pc2_30m2h64bp ['pc2_30m2h64bp']
# pc2_30m2h128bp ['pc2_30m2h128bp']

# %%
fig.savefig('plots/step_15m.svg')

# %%
# Use this to look at what datasets are available :)
import pickle
name = 'data/LDS_response_LONG.pickle'
with open(name,'rb') as f:
    result = pickle.load(f)
print(result.keys())
# Out:
# dict_keys(['tau', 'WT_30m2h16bp', 'WT_30m2h8bp', 'chat_30m2h8bp', 'chat+pc2_30m2h8bp', 'WT_30m2h32bp', 'WT_30m2h4bp', 'WT_5m2h255bp', 'WT_30m2h1,2,4,8bp', 'arx_30m2h8bp', 'nkx_30m2h8bp', '121321WT_30m2h16bp', '121321WT_30m2h32bp', '121621WT_30m2h128bp', '121621WT_30m2h64bp', 'tcf_30m2h8bp', '122821pc2_30m2h16bp', '122821pc2_8only_30m2h16bp', '122821pc2_8only_30m2h32bp', 'tbh_30m2h8bp', 'gad_30m2h8bp', 'pc2_30m2h128bp', 'tbh+pc2_30m2h64bp', 'corpusCut_30m2h64bp', '35mmBiopsyPostEyespot_30m2h64bp', 'if1_30m2h64bp', 'cali_30m2h64bp', 'estrella_30m2h64bp', 'amp1xPostEyespot', 'chat_30m2h64bp', 'pc2_30m2h64bp', 'tcf1_30m2h64bp', 'tcf1+pc2_30m2h64bp', 'slit_30m2h64bp', 'WTampMidEyespotPharynx_30s', '040122WTampPostEyespot_30s', 'chat+pc2_30m2h64bp', '042522estrella_30m2h64bp', '042522cali_30m2h64bp', 'tec1_30m2h64bp', 'starve10w_30m2h64bp', 'tbh_30m2h64bp', '051122WT_30m2h64bp', '051822WT_30m2h64bp', '061622eye532_30m2h64bp', '061622ppp1_30m2h64bp', '061622spp1_30m2h64bp', '062322estrella+if1+cali_30m2h64bp', '062322estrella+if1_30m2h64bp', '062322estrella+cali_30m2h64bp'])

# %%
from tools.results_step import response_scaling
n_boot = 1e3

fig,ax=response_scaling(n_boot = n_boot)
# Out:
# WT_30m2h4bp ['WT_30m2h4bp']
# WT_30m2h8bp ['WT_30m2h8bp']
# WT_30m2h16bp ['WT_30m2h16bp', '121321WT_30m2h16bp']
# WT_30m2h32bp ['WT_30m2h32bp', '121321WT_30m2h32bp']
# WT_30m2h64bp ['121621WT_30m2h64bp', '051122WT_30m2h64bp', '051822WT_30m2h64bp']
# WT_30m2h128bp ['121621WT_30m2h128bp']
