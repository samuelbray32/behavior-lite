# %%
from tools.results_noise import autocovariance
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig,ax=autocovariance(n_boot=1e2,sample_range=(20,60),
                      tau = np.arange(1,30*120,10))
fig.show()
# Out:
# ['102122WT_60m_128Mean_64Amp_100msRefresh']
# /home/sam/anaconda3/envs/imgBehavior-tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   import sys

# %%
ax.set_xlim(0,12)
plt.rcParams['svg.fonttype']='none'
fig.savefig('plots/noise_autocovariance.svg')

# %%
import numpy as np

# %%
from tools.results_noise import autocovariance_step
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig,ax=autocovariance_step(['WT','pc2',],exclude=['+'],n_boot=1e3,sample_range=(15,30),
                      tau = np.arange(1,12*120,2))
fig.show()
# Out:
# WT
# WT_30m2h64bp ['121621WT_30m2h64bp', '051122WT_30m2h64bp', '051822WT_30m2h64bp']
# ['121621WT_30m2h64bp', '051122WT_30m2h64bp', '051822WT_30m2h64bp']
# pc2
# tbh+pc2_30m2h64bp
# tcf1+pc2_30m2h64bp
# chat+pc2_30m2h64bp
# 070522th+pc2_30m2h64bp
# pc2_30m2h64bp ['pc2_30m2h64bp']
# ['pc2_30m2h64bp']
# /home/sam/anaconda3/envs/imgBehavior-tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   import sys
