# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.bootstrapTest import bootstrap_traces
from tools.results import data_of_interest
from tools.results import rnai_response_layered

# %% [markdown]
# ## Compiled Plot
# Compiles all valid 5s and 30s datasets for each knockdownlisted in the interest list and runs bootstrap estimates on the complete set of traces
#
# Note: printout lists are all datasets that are compiled for each condition.  Please check that what is being compiled is what you want!

# %%
n_boot = 1e2
statistic=np.median
comparison = 'rel'
#plot_subset
drugs=0
interest = ['pc2']#['chat','gad','tbh',]#['snap25','vGlut']#['nkx','tcf1','arx']#['35mmBiopsyPostEyespot','corpusCut']#
exclude = ['+']
fig,ax = rnai_response_layered(interest,exclude,n_boot,statistic,drugs=drugs,
                              measure_compare=comparison)
# fig.savefig('layered_pc2.svg')
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 229.06it/s]
# 100%|██████████| 300/300 [00:01<00:00, 244.20it/s]
# 100%|██████████| 300/300 [00:01<00:00, 240.35it/s]
# 100%|██████████| 300/300 [00:00<00:00, 34745.03it/s]
# 100%|██████████| 300/300 [00:00<00:00, 310.68it/s]
# 100%|██████████| 300/300 [00:00<00:00, 332.96it/s]
# 100%|██████████| 300/300 [00:00<00:00, 333.39it/s]
# 100%|██████████| 300/300 [00:00<00:00, 38969.66it/s]
# ['022421pc2_5s', '022421pc2']
# 100%|██████████| 300/300 [00:00<00:00, 351.86it/s]
# 100%|██████████| 300/300 [00:00<00:00, 378.75it/s]
# 100%|██████████| 300/300 [00:00<00:00, 376.63it/s]
# 100%|██████████| 300/300 [00:00<00:00, 39360.96it/s]
# ['pc2_30s', '022421pc2_30s']
# 100%|██████████| 300/300 [00:01<00:00, 195.66it/s]
# 100%|██████████| 300/300 [00:01<00:00, 207.34it/s]
# 100%|██████████| 300/300 [00:01<00:00, 207.68it/s]
# 100%|██████████| 300/300 [00:00<00:00, 36535.75it/s]
