# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.bootstrapTest import bootstrap_traces
from tools.results import data_of_interest
from tools.results import rnai_response_layered

# %%
n_boot = 1e3
statistic=np.median
#plot_subset
drugs=0
interest = ['pc2']#['chat','gad','tbh',]#['snap25','vGlut']#['nkx','tcf1','otxa','foxq2']#
exclude = ['+']
interest=['gad','pc2','gad+pc2']
exclude=['_5s']
fig,ax = rnai_response_layered(interest,exclude,n_boot,statistic,drugs=drugs)
# fig.savefig('layered_pc2.svg')
# Out:
# ['gad120120', '100421gad']
# ['gad_30s', '100421gad_30s']
# ['022421pc2']
# ['pc2_30s', '022421pc2_30s']
# ['gad+pc2']
# ['gad+pc2_30s']

# %%
# fig.savefig('layered_gad+pc2.svg')
