# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.bootstrapTest import bootstrap_traces
from tools.results import data_of_interest
from tools.results import rnai_response_layered

# %% [markdown]
# ## Compiled Plot
# Compiles all valid 5s and 30s datasets for each knockdownlisted in the interest list and runs bootstrap estimates on the complete set of traces
#
# Note: printout lists are all datasets that are compiled for each condition.  Please check that what is being compiled is what you want!

# %%
n_boot = 3e2
statistic=np.median
comparison = 'rel'
#plot_subset
drugs=0
interest = ['pc2']#['corpusCut','spot']#['pc2','chat','gad','tbh','th','nkx','tcf1']#['spot']#['eaat12','gs','gat',]#['chat','gad','tbh',]#['snap25','vGlut']#['nkx','tcf1','arx']#['35mmBiopsyPostEyespot','corpusCut']#
exclude = ['+','122721']
fig,ax = rnai_response_layered(interest,exclude,n_boot,statistic,drugs=drugs,
                              measure_compare=comparison,
                              pulseTimes=[1,5,30,60])
# fig.savefig('layered_pc2.svg')
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 212.33it/s]
# 100%|██████████| 300/300 [00:01<00:00, 230.75it/s]
# 100%|██████████| 300/300 [00:01<00:00, 209.25it/s]
# 100%|██████████| 300/300 [00:01<00:00, 201.98it/s]
# 100%|██████████| 300/300 [00:00<00:00, 303.05it/s]
# 100%|██████████| 300/300 [00:00<00:00, 311.11it/s]
# 100%|██████████| 300/300 [00:00<00:00, 322.60it/s]
# 100%|██████████| 300/300 [00:00<00:00, 326.39it/s]
# 1 ['+', '122721']
# ['pc2_1s']
# 100%|██████████| 300/300 [00:00<00:00, 341.62it/s]
# 100%|██████████| 300/300 [00:00<00:00, 336.76it/s]
# 5 ['+', '122721']
# ['022421pc2']
# 100%|██████████| 300/300 [00:00<00:00, 619.03it/s]
# 100%|██████████| 300/300 [00:00<00:00, 646.81it/s]
# 30 ['+', '122721']
# ['pc2_30s', '022421pc2_30s']
# 100%|██████████| 300/300 [00:01<00:00, 168.80it/s]
# 100%|██████████| 300/300 [00:01<00:00, 179.90it/s]
# 60 ['+', '122721']
# ['pc2_60s']
# 100%|██████████| 300/300 [00:00<00:00, 333.25it/s]
# 100%|██████████| 300/300 [00:00<00:00, 370.10it/s]

# %%
fig.savefig('singlePulse_Fig1.svg')

# %%
fig.savefig('singlePulse_Fig1.svg')

# %%
# %matplotlib inline
fig.axes[-1].set_ylim(.1,20)
plt.show()
