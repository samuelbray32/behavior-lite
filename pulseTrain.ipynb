# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.results import pulseTrain_WT

# %%
fig,ax = pulseTrain_WT(isi=[15,30,45,60,120,],n_boot=1e3,norm_time=True,trial_rng=(2,200))
# Out:
# ['062921WT_1s15s_n20_2hITI'] (49, 12600)
# ['060221WT_1s30s_n20_2hITI'] (56, 12600)
# ['062921WT_1s45s_n20_2hITI'] (57, 12600)
# ['061521WT_1s1m_n20_2hITI'] (257, 12600)
# ['061521WT_1s2m_n20_2hITI'] (97, 12600)
