# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
from tools.results import pulseTrain_WT

# %% [markdown]
# ### User guide
# ##### *Note: only one list (pulse, isi, or iti) can have multiple elements in a given plot
#
# _pulse_: duration(s) of each stimulus (in seconds)
#
# _isi_: time between stimuli (in seconds)
#
# _iti_: time between trials (in hours)
#
# _n_: number of pulses in trial
#
# _statistic_: what statistic to sample with the bootstrap (default is median)

# %%
# pulse=[1]
# isi=[15,30,45,60,]
# n=20

pulse=[1,2,5]
isi=[60,]
n=10
# isi.reverse()
fig,ax = pulseTrain_WT(pulse=pulse,isi=isi,n_boot=1e2,norm_time=1,trial_rng=(0,50),n=n,
                      integrate=30)
# Out:
# ['052321WT_1s1m_n10_2hITI'] (73, 12600)
# ['060821WT_2s1m_n10_2hITI'] (58, 12600)
# ['051321WT_5s1m_n10_2hITI'] (114, 12600)
