# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'

# %%
from tools.results_pairedPulse import compareDelays
delay=[.5,1,2,3,5,30]
fig,ax=compareDelays(delay=delay,n_boot=1e3)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 167.99it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 496.19it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 346.92it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 378.75it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 144.65it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 171.98it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 303.79it/s]

# %%
from tools.results_pairedPulse import compareFirstPulse

fig,ax=compareFirstPulse(n_boot=1e3)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 169.05it/s]
# [1, 5, 10]
# 100%|██████████| 1000/1000 [00:02<00:00, 498.26it/s]
# 100%|██████████| 1000/1000 [00:06<00:00, 143.49it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 396.98it/s]
# (<Figure size 432x288 with 1 Axes>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0x7f0f14181d90>])
